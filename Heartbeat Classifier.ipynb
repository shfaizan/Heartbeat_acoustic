# %%
import os
import glob
import numpy as np
from tqdm import tqdm
import itertools
import matplotlib.pyplot as plt
import pandas as pd

# Audio
import librosa
import librosa.display

# Scikit learn
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import shuffle
from sklearn.utils import class_weight

# Keras
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.utils import to_categorical

import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# %% [markdown]
# ## Loading Dataset
#
# Considering only more than 3 sec files and
# labelling the files as Normal or Abnormal

# %% [markdown]
# TODO: Add artifacts (i.e. noises without heartbeat data) and ask the user to try again

# %%
dataset = []
for folder in ["./set_a/**","./set_b/**"]:
    for filename in glob.iglob(folder):
        if os.path.exists(filename):
            label = os.path.basename(filename).split("_")[0]
            duration = librosa.get_duration(filename=filename)
            # skip audio smaller than 3 secs
            if duration>=3:
                slice_size = 3
                iterations = int((duration-slice_size)/(slice_size-1))
                iterations += 1
#                 initial_offset = (duration % slice_size)/2
                initial_offset = (duration - ((iterations*(slice_size-1))+1))/2
                if label not in ["Aunlabelledtest", "Bunlabelledtest", "artifact"]:
                    for i in range(iterations):
                        offset = initial_offset + i*(slice_size-1)
                        if (label == "normal"):
                            dataset.append({
                                "filename": filename,
                                "label": "normal",
                                "offset": offset
                            })
                        else:
                            dataset.append({
                                "filename": filename,
                                "label": "abnormal",
                                "offset": offset
                            })
                        
dataset = pd.DataFrame(dataset)
dataset = shuffle(dataset, random_state=42)
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1281 entries, 1241 to 1126
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  1281 non-null   object
#  1   label     1281 non-null   object
#  2   offset    1281 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 40.0+ KB

# %%
plt.figure(figsize=(4,6))
dataset.label.value_counts().plot(kind='bar', title="Dataset distribution")
plt.show()

# %% [markdown]
# ## Split dataset in train and test
# 80-20 Ratio

# %%
train, test = train_test_split(dataset, test_size=0.2, random_state=42)

print("Train: %i" % len(train))
print("Test: %i" % len(test))
# Out:
# Train: 1024
# Test: 257

# %% [markdown]
# ## Visualising the data and features

# %%
plt.figure(figsize=(20,10))
idx = 0
for label in dataset.label.unique():    
    y, sr = librosa.load(dataset[dataset.label==label].filename.iloc[33], duration=3)
    print(dataset[dataset.label==label].filename.iloc[33])
    
    # Wave plot
    idx+=1
    plt.subplot(2, 3, idx)
    plt.title("%s waveplot" % label)
    librosa.display.waveplot(y, sr=sr)

    # Mel Spectrogram
    idx+=1
    plt.subplot(2, 3, idx)
    S = librosa.feature.melspectrogram(y, sr=sr, n_fft=2048, hop_length=512, n_mels=128)
    S_DB = librosa.power_to_db(S, ref=np.max)
    librosa.display.specshow(S_DB, sr=sr, hop_length=512, x_axis='time', y_axis='mel')
    plt.title("%s mel spectogram" % label)

    # MFCC (Mel spectrogram)
    idx+=1
    mfccs = librosa.feature.mfcc(S=librosa.power_to_db(S), n_mfcc=40)
    plt.subplot(2, 3, idx)
    librosa.display.specshow(mfccs, x_axis='time')
    plt.title("%s mfcc(Mel Spectrogram)" % label)
plt.show()
# Out:
# ./set_b\normal__137_1306764999211_C.wav
# ./set_b\extrastole__220_1308250132896_B.wav

# %% [markdown]
# ## Extracting features

# %%
def extract_features(audio_path,offset):
#     y, sr = librosa.load(audio_path, duration=3)
    y, sr = librosa.load(audio_path, offset=offset, duration=3)
#     y = librosa.util.normalize(y)
    
    S = librosa.feature.melspectrogram(y, sr=sr, n_fft=2048, 
                                   hop_length=512, 
                                   n_mels=128)
    mfccs = librosa.feature.mfcc(S=librosa.power_to_db(S), n_mfcc=40)

#     mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40)
    return mfccs

# %%
x_train = []
x_test = []

for idx in tqdm(range(len(train))):
    x_train.append(extract_features(train.filename.iloc[idx],train.offset.iloc[idx]))

for idx in tqdm(range(len(test))):
    x_test.append(extract_features(test.filename.iloc[idx],test.offset.iloc[idx]))
    
x_test = np.asarray(x_test)
x_train = np.asarray(x_train)

print("X train:", x_train.shape)
print("X test:", x_test.shape)
# Out:
# 100%|██████████| 1024/1024 [01:35<00:00, 10.71it/s]
# 100%|██████████| 257/257 [00:23<00:00, 10.84it/s]
# X train: (1024, 40, 130)
# X test: (257, 40, 130)

# %%
# Encode Labels
encoder = LabelEncoder()
encoder.fit(train.label)

y_train = encoder.transform(train.label)
y_test = encoder.transform(test.label)

# Compute class weights
print(np.unique(y_train))

class_test = class_weight.compute_class_weight('balanced',np.unique(y_train),y_train)
class_weights = {0:class_test[0],1:class_test[1]}
print(class_weights)
print(type(class_weights))
# Out:
# [0 1]
# {0: 1.2673267326732673, 1: 0.8258064516129032}
# <class 'dict'>

# %% [markdown]
# ## Input Shapes

# %%
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], x_test.shape[2], 1)
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

print("X train:", x_train.shape)
print("Y train:", y_train.shape)
print("X test:", x_test.shape)
print("Y test:", y_test.shape)
# Out:
# X train: (1024, 40, 130, 1)
# Y train: (1024, 2)
# X test: (257, 40, 130, 1)
# Y test: (257, 2)

# %% [markdown]
# ## Building Model

# %%
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, input_shape=(x_train.shape[1],x_train.shape[2],x_train.shape[3]), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=32, kernel_size=2, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=2, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=128, kernel_size=2, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.5))
model.add(GlobalAveragePooling2D())

model.add(Dense(len(encoder.classes_), activation='softmax'))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 39, 129, 16)       80
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 19, 64, 16)        0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 19, 64, 16)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 18, 63, 32)        2080
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 9, 31, 32)         0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 9, 31, 32)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 8, 30, 64)         8256
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 4, 15, 64)         0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 4, 15, 64)         0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 3, 14, 128)        32896
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 1, 7, 128)         0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 1, 7, 128)         0
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 43,570
# Trainable params: 43,570
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compiling Model

# %%
adam = keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %% [markdown]
# ## Fitting Model

# %%
# %%time
history = model.fit(x_train, y_train,
              batch_size=128,
              epochs=300,
              validation_data=(x_test, y_test),
              class_weight=class_weights,
              shuffle=True)
# Out:
# Epoch 1/300
# 8/8 [==============================] - 1s 117ms/step - loss: 11.6182 - accuracy: 0.5107 - val_loss: 3.7032 - val_accuracy: 0.4202
# Epoch 2/300
# 8/8 [==============================] - 0s 44ms/step - loss: 4.8624 - accuracy: 0.5449 - val_loss: 0.7445 - val_accuracy: 0.6926
# Epoch 3/300
# 8/8 [==============================] - 0s 42ms/step - loss: 3.0663 - accuracy: 0.5088 - val_loss: 0.6263 - val_accuracy: 0.6732
# Epoch 4/300
# 8/8 [==============================] - 0s 47ms/step - loss: 2.0400 - accuracy: 0.5908 - val_loss: 0.8202 - val_accuracy: 0.5525
# Epoch 5/300
# 8/8 [==============================] - 0s 44ms/step - loss: 1.6537 - accuracy: 0.5400 - val_loss: 0.5870 - val_accuracy: 0.6926
# Epoch 6/300
# 8/8 [==============================] - 0s 45ms/step - loss: 1.4899 - accuracy: 0.5742 - val_loss: 0.7711 - val_accuracy: 0.4553
# Epoch 7/300
# 8/8 [==============================] - 0s 45ms/step - loss: 1.2453 - accuracy: 0.5557 - val_loss: 0.6693 - val_accuracy: 0.5486
# Epoch 8/300
# 8/8 [==============================] - 0s 39ms/step - loss: 1.1372 - accuracy: 0.5527 - val_loss: 0.7279 - val_accuracy: 0.4630
# Epoch 9/300
# 8/8 [==============================] - 0s 50ms/step - loss: 1.0279 - accuracy: 0.5801 - val_loss: 0.6956 - val_accuracy: 0.5214
# Epoch 10/300
# 8/8 [==============================] - 0s 51ms/step - loss: 0.9791 - accuracy: 0.5684 - val_loss: 0.6680 - val_accuracy: 0.5992
# Epoch 11/300
# 8/8 [==============================] - 0s 42ms/step - loss: 0.8713 - accuracy: 0.5820 - val_loss: 0.6594 - val_accuracy: 0.6498
# Epoch 12/300
# 8/8 [==============================] - 0s 42ms/step - loss: 0.8607 - accuracy: 0.5811 - val_loss: 0.6743 - val_accuracy: 0.6070
# Epoch 13/300
# 8/8 [==============================] - 0s 40ms/step - loss: 0.8137 - accuracy: 0.5859 - val_loss: 0.6497 - val_accuracy: 0.6770
# Epoch 14/300
# 8/8 [==============================] - 0s 41ms/step - loss: 0.7662 - accuracy: 0.6045 - val_loss: 0.6403 - val_accuracy: 0.6965
# Epoch 15/300
# 8/8 [==============================] - 0s 40ms/step - loss: 0.7041 - accuracy: 0.6123 - val_loss: 0.6321 - val_accuracy: 0.6965
# Epoch 16/300
# 8/8 [==============================] - 1s 63ms/step - loss: 0.7147 - accuracy: 0.6172 - val_loss: 0.6244 - val_accuracy: 0.7043
# Epoch 17/300
# 8/8 [==============================] - 0s 45ms/step - loss: 0.6821 - accuracy: 0.6191 - val_loss: 0.6218 - val_accuracy: 0.7237
# Epoch 18/300
# 8/8 [==============================] - 0s 48ms/step - loss: 0.6981 - accuracy: 0.6240 - val_loss: 0.6291 - val_accuracy: 0.7082
# Epoch 19/300
# 8/8 [==============================] - 1s 63ms/step - loss: 0.6820 - accuracy: 0.6592 - val_loss: 0.6092 - val_accuracy: 0.7198
# Epoch 20/300
# 8/8 [==============================] - 0s 51ms/step - loss: 0.6720 - accuracy: 0.6270 - val_loss: 0.6165 - val_accuracy: 0.7315
# Epoch 21/300
# 8/8 [==============================] - 0s 43ms/step - loss: 0.6447 - accuracy: 0.6729 - val_loss: 0.6248 - val_accuracy: 0.7393
# Epoch 22/300
# 8/8 [==============================] - 0s 46ms/step - loss: 0.6360 - accuracy: 0.6494 - val_loss: 0.6223 - val_accuracy: 0.7198
# Epoch 23/300
# 8/8 [==============================] - 0s 51ms/step - loss: 0.6393 - accuracy: 0.6562 - val_loss: 0.6116 - val_accuracy: 0.7354
# Epoch 24/300
# 8/8 [==============================] - 0s 40ms/step - loss: 0.6408 - accuracy: 0.6426 - val_loss: 0.5963 - val_accuracy: 0.7121
# Epoch 25/300
# 8/8 [==============================] - 1s 67ms/step - loss: 0.6329 - accuracy: 0.6426 - val_loss: 0.5940 - val_accuracy: 0.7043
# Epoch 26/300
# 8/8 [==============================] - 0s 51ms/step - loss: 0.6391 - accuracy: 0.6572 - val_loss: 0.5944 - val_accuracy: 0.7121
# Epoch 27/300
# 8/8 [==============================] - 0s 57ms/step - loss: 0.6228 - accuracy: 0.6641 - val_loss: 0.5843 - val_accuracy: 0.7276
# Epoch 28/300
# 8/8 [==============================] - 0s 41ms/step - loss: 0.6187 - accuracy: 0.6680 - val_loss: 0.5841 - val_accuracy: 0.7432
# Epoch 29/300
# 8/8 [==============================] - 0s 56ms/step - loss: 0.5929 - accuracy: 0.6855 - val_loss: 0.5775 - val_accuracy: 0.7393
# Epoch 30/300
# 8/8 [==============================] - 0s 47ms/step - loss: 0.5845 - accuracy: 0.6914 - val_loss: 0.5729 - val_accuracy: 0.7198
# Epoch 31/300
# 8/8 [==============================] - 0s 49ms/step - loss: 0.6078 - accuracy: 0.6865 - val_loss: 0.5745 - val_accuracy: 0.7160
# Epoch 32/300
# 8/8 [==============================] - 1s 63ms/step - loss: 0.6094 - accuracy: 0.6689 - val_loss: 0.5782 - val_accuracy: 0.7354
# Epoch 33/300
# 8/8 [==============================] - 1s 67ms/step - loss: 0.6011 - accuracy: 0.6738 - val_loss: 0.5835 - val_accuracy: 0.7276
# Epoch 34/300
# 8/8 [==============================] - 0s 42ms/step - loss: 0.5781 - accuracy: 0.6973 - val_loss: 0.5715 - val_accuracy: 0.7393
# Epoch 35/300
# 8/8 [==============================] - 0s 42ms/step - loss: 0.5886 - accuracy: 0.6973 - val_loss: 0.5564 - val_accuracy: 0.7315
# Epoch 36/300
# 8/8 [==============================] - 1s 150ms/step - loss: 0.5922 - accuracy: 0.7012 - val_loss: 0.5574 - val_accuracy: 0.7276
# Epoch 37/300
# 8/8 [==============================] - 0s 41ms/step - loss: 0.5801 - accuracy: 0.6982 - val_loss: 0.5628 - val_accuracy: 0.7471
# Epoch 38/300
# 8/8 [==============================] - 0s 45ms/step - loss: 0.5941 - accuracy: 0.6973 - val_loss: 0.5624 - val_accuracy: 0.7237
# Epoch 39/300
# 8/8 [==============================] - 0s 50ms/step - loss: 0.5883 - accuracy: 0.6836 - val_loss: 0.5634 - val_accuracy: 0.7393
# Epoch 40/300
# 8/8 [==============================] - 1s 74ms/step - loss: 0.5855 - accuracy: 0.6963 - val_loss: 0.5586 - val_accuracy: 0.7198
# Epoch 41/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.5865 - accuracy: 0.6689 - val_loss: 0.5549 - val_accuracy: 0.7315
# Epoch 42/300
# 8/8 [==============================] - 0s 52ms/step - loss: 0.5691 - accuracy: 0.7139 - val_loss: 0.5679 - val_accuracy: 0.7432
# Epoch 43/300
# 8/8 [==============================] - 1s 92ms/step - loss: 0.5681 - accuracy: 0.6992 - val_loss: 0.5489 - val_accuracy: 0.7510
# Epoch 44/300
# 8/8 [==============================] - 1s 76ms/step - loss: 0.5726 - accuracy: 0.7002 - val_loss: 0.5419 - val_accuracy: 0.7549
# Epoch 45/300
# 8/8 [==============================] - 0s 51ms/step - loss: 0.5667 - accuracy: 0.7012 - val_loss: 0.5382 - val_accuracy: 0.7354
# Epoch 46/300
# 8/8 [==============================] - 0s 62ms/step - loss: 0.5559 - accuracy: 0.7188 - val_loss: 0.5425 - val_accuracy: 0.7432
# Epoch 47/300
# 8/8 [==============================] - 0s 51ms/step - loss: 0.5728 - accuracy: 0.7090 - val_loss: 0.5358 - val_accuracy: 0.7393
# Epoch 48/300
# 8/8 [==============================] - 0s 58ms/step - loss: 0.5727 - accuracy: 0.6914 - val_loss: 0.5404 - val_accuracy: 0.7432
# Epoch 49/300
# 8/8 [==============================] - 0s 61ms/step - loss: 0.5564 - accuracy: 0.6963 - val_loss: 0.5286 - val_accuracy: 0.7743
# Epoch 50/300
# 8/8 [==============================] - 1s 67ms/step - loss: 0.5550 - accuracy: 0.6953 - val_loss: 0.5360 - val_accuracy: 0.7471
# Epoch 51/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.5603 - accuracy: 0.7080 - val_loss: 0.5524 - val_accuracy: 0.7432
# Epoch 52/300
# 8/8 [==============================] - 1s 70ms/step - loss: 0.5605 - accuracy: 0.7090 - val_loss: 0.5343 - val_accuracy: 0.7315
# Epoch 53/300
# 8/8 [==============================] - 1s 75ms/step - loss: 0.5550 - accuracy: 0.7021 - val_loss: 0.5311 - val_accuracy: 0.7510
# Epoch 54/300
# 8/8 [==============================] - 0s 50ms/step - loss: 0.5672 - accuracy: 0.6895 - val_loss: 0.5255 - val_accuracy: 0.7588
# Epoch 55/300
# 8/8 [==============================] - 1s 65ms/step - loss: 0.5430 - accuracy: 0.7344 - val_loss: 0.5436 - val_accuracy: 0.7471
# Epoch 56/300
# 8/8 [==============================] - 0s 44ms/step - loss: 0.5511 - accuracy: 0.7051 - val_loss: 0.5188 - val_accuracy: 0.7549
# Epoch 57/300
# 8/8 [==============================] - 0s 38ms/step - loss: 0.5573 - accuracy: 0.7012 - val_loss: 0.5247 - val_accuracy: 0.7626
# Epoch 58/300
# 8/8 [==============================] - 0s 61ms/step - loss: 0.5421 - accuracy: 0.7207 - val_loss: 0.5196 - val_accuracy: 0.7471
# Epoch 59/300
# 8/8 [==============================] - 0s 48ms/step - loss: 0.5498 - accuracy: 0.7188 - val_loss: 0.5345 - val_accuracy: 0.7393
# Epoch 60/300
# 8/8 [==============================] - 0s 50ms/step - loss: 0.5546 - accuracy: 0.7090 - val_loss: 0.5383 - val_accuracy: 0.7393
# Epoch 61/300
# 8/8 [==============================] - 0s 51ms/step - loss: 0.5528 - accuracy: 0.7031 - val_loss: 0.5184 - val_accuracy: 0.7588
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2805 - accuracy: 0.8789 - val_loss: 0.3451 - val_accuracy: 0.8288
# Epoch 276/300
# 8/8 [==============================] - 1s 136ms/step - loss: 0.2800 - accuracy: 0.8779 - val_loss: 0.3436 - val_accuracy: 0.8366
# Epoch 277/300
# 8/8 [==============================] - 0s 53ms/step - loss: 0.3166 - accuracy: 0.8555 - val_loss: 0.3232 - val_accuracy: 0.8210
# Epoch 278/300
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2883 - accuracy: 0.8682 - val_loss: 0.3334 - val_accuracy: 0.8677
# Epoch 279/300
# 8/8 [==============================] - 0s 54ms/step - loss: 0.2837 - accuracy: 0.8750 - val_loss: 0.3268 - val_accuracy: 0.8560
# Epoch 280/300
# 8/8 [==============================] - 0s 47ms/step - loss: 0.3000 - accuracy: 0.8740 - val_loss: 0.3580 - val_accuracy: 0.8210
# Epoch 281/300
# 8/8 [==============================] - 0s 40ms/step - loss: 0.3044 - accuracy: 0.8643 - val_loss: 0.3343 - val_accuracy: 0.8327
# Epoch 282/300
# 8/8 [==============================] - 0s 40ms/step - loss: 0.2921 - accuracy: 0.8691 - val_loss: 0.3238 - val_accuracy: 0.8444
# Epoch 283/300
# 8/8 [==============================] - 0s 55ms/step - loss: 0.2743 - accuracy: 0.8877 - val_loss: 0.3622 - val_accuracy: 0.8327
# Epoch 284/300
# 8/8 [==============================] - 0s 43ms/step - loss: 0.2703 - accuracy: 0.8926 - val_loss: 0.3326 - val_accuracy: 0.8327
# Epoch 285/300
# 8/8 [==============================] - 1s 137ms/step - loss: 0.2714 - accuracy: 0.8623 - val_loss: 0.3265 - val_accuracy: 0.8327
# Epoch 286/300
# 8/8 [==============================] - 0s 46ms/step - loss: 0.3012 - accuracy: 0.8730 - val_loss: 0.3331 - val_accuracy: 0.8327
# Epoch 287/300
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2885 - accuracy: 0.8721 - val_loss: 0.3452 - val_accuracy: 0.8288
# Epoch 288/300
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2905 - accuracy: 0.8760 - val_loss: 0.3493 - val_accuracy: 0.8366
# Epoch 289/300
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2683 - accuracy: 0.8896 - val_loss: 0.3503 - val_accuracy: 0.8366
# Epoch 290/300
# 8/8 [==============================] - 1s 65ms/step - loss: 0.2679 - accuracy: 0.8828 - val_loss: 0.3327 - val_accuracy: 0.8249
# Epoch 291/300
# 8/8 [==============================] - 1s 63ms/step - loss: 0.2985 - accuracy: 0.8652 - val_loss: 0.3235 - val_accuracy: 0.8599
# Epoch 292/300
# 8/8 [==============================] - 0s 61ms/step - loss: 0.2919 - accuracy: 0.8779 - val_loss: 0.3304 - val_accuracy: 0.8482
# Epoch 293/300
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2877 - accuracy: 0.8711 - val_loss: 0.3233 - val_accuracy: 0.8482
# Epoch 294/300
# 8/8 [==============================] - 0s 58ms/step - loss: 0.2815 - accuracy: 0.8584 - val_loss: 0.3283 - val_accuracy: 0.8599
# Epoch 295/300
# 8/8 [==============================] - 0s 54ms/step - loss: 0.2783 - accuracy: 0.8779 - val_loss: 0.3234 - val_accuracy: 0.8405
# Epoch 296/300
# 8/8 [==============================] - 0s 54ms/step - loss: 0.2700 - accuracy: 0.8936 - val_loss: 0.3835 - val_accuracy: 0.7899
# Epoch 297/300
# 8/8 [==============================] - 0s 55ms/step - loss: 0.2736 - accuracy: 0.8740 - val_loss: 0.3273 - val_accuracy: 0.8444
# Epoch 298/300
# 8/8 [==============================] - 0s 41ms/step - loss: 0.2739 - accuracy: 0.8779 - val_loss: 0.3121 - val_accuracy: 0.8482
# Epoch 299/300
# 8/8 [==============================] - 0s 45ms/step - loss: 0.2825 - accuracy: 0.8799 - val_loss: 0.3222 - val_accuracy: 0.8560
# Epoch 300/300
# 8/8 [==============================] - 0s 41ms/step - loss: 0.2653 - accuracy: 0.8887 - val_loss: 0.3218 - val_accuracy: 0.8249
# Wall time: 2min 11s

# %% [markdown]
# ## Evaluating model

# %%
# Loss Curves
plt.figure(figsize=[14,10])
plt.subplot(211)
plt.plot(history.history['loss'],'#d62728',linewidth=3.0)
plt.plot(history.history['val_loss'],'#1f77b4',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=16)
 
# Accuracy Curves
plt.figure(figsize=[14,10])
plt.subplot(212)
plt.plot(history.history['accuracy'],'#d62728',linewidth=3.0)
plt.plot(history.history['val_accuracy'],'#1f77b4',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Accuracy',fontsize=16)
plt.title('Accuracy Curves',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Accuracy Curves')

# %%
print(x_test.shape)
print(y_train.shape)
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# (257, 40, 130, 1)
# (1024, 2)
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3218 - accuracy: 0.8249
# Test loss: 0.32177209854125977
# Test accuracy: 0.8249027132987976

# %%
predictions = model.predict(x_test, verbose=1)

y_true, y_pred = [],[]
classes = encoder.classes_
for idx, prediction in enumerate(predictions): 
    y_true.append(classes[np.argmax(y_test[idx])])
    y_pred.append(classes[np.argmax(prediction)])
    
print(classification_report(y_pred, y_true))
# Out:
# 9/9 [==============================] - 0s 5ms/step
#               precision    recall  f1-score   support
#
#     abnormal       0.77      0.81      0.79       103
#       normal       0.87      0.84      0.85       154
#
#     accuracy                           0.82       257
#    macro avg       0.82      0.82      0.82       257
# weighted avg       0.83      0.82      0.83       257

# %% [markdown]
# ### Save Model and Weights

# %%
model_name = "heartbeat_classifier (normalised).h5"
model.save(model_name)

# %%
# 1 sec overlap
# Trained for 3sec for files >3sec

# %% [markdown]
# ### Classifying an heart beat

# %%
# load and evaluate a saved model
from keras.models import load_model
 
# load model
model = load_model("heartbeat_classifier.h5")

# File to be classified
classify_file = "c0001.wav"
x_test = []
x_test.append(extract_features(classify_file,0.5))
x_test = np.asarray(x_test)
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], x_test.shape[2], 1)
pred = model.predict(x_test,verbose=1)

print(pred)
# Out:
# 1/1 [==============================] - 0s 3ms/step
# [[0.9979917  0.00200832]]

# %%
pred_class = model.predict_classes(x_test)
if pred_class[0]:
    print("Normal heartbeat")
    print("confidence:",pred[0][1])
else:
    print("Abnormal heartbeat")
    print("confidence:",pred[0][0])
# Out:
# WARNING:tensorflow:From <ipython-input-61-321101c504e4>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# Abnormal heartbeat
# confidence: 0.9979917
