# %%
import os
import glob
import numpy as np
from tqdm import tqdm
import itertools
import matplotlib.pyplot as plt
import pandas as pd

# Audio
import librosa
import librosa.display

# Scikit learn
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import shuffle
from sklearn.utils import class_weight

# Keras
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.utils import to_categorical

import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# %% [markdown]
# ## Loading Dataset
#
# Considering only more than 3 sec files and
# labelling the files as Normal or Abnormal

# %% [markdown]
# TODO: Add artifacts (i.e. noises without heartbeat data) and ask the user to try again

# %%
dataset = []
for folder in ["./set_a/**","./set_b/**"]:
    for filename in glob.iglob(folder):
        if os.path.exists(filename):
            label = os.path.basename(filename).split("_")[0]
            duration = librosa.get_duration(filename=filename)
            # skip audio smaller than 3 secs
            if duration>=3:
                slice_size = 3
                iterations = int((duration-slice_size)/(slice_size-1))
                iterations += 1
#                 initial_offset = (duration % slice_size)/2
                initial_offset = (duration - ((iterations*(slice_size-1))+1))/2
                if label not in ["Aunlabelledtest", "Bunlabelledtest", "artifact"]:
                    for i in range(iterations):
                        offset = initial_offset + i*(slice_size-1)
                        if (label == "normal"):
                            dataset.append({
                                "filename": filename,
                                "label": "normal",
                                "offset": offset
                            })
                        else:
                            dataset.append({
                                "filename": filename,
                                "label": "abnormal",
                                "offset": offset
                            })
                        
dataset = pd.DataFrame(dataset)
dataset = shuffle(dataset, random_state=42)
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1281 entries, 1241 to 1126
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  1281 non-null   object
#  1   label     1281 non-null   object
#  2   offset    1281 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 40.0+ KB

# %%
plt.figure(figsize=(14,6))
dataset.label.value_counts().plot(kind='barh', title="Dataset distribution")
plt.show()

# %% [markdown]
# ## Split dataset in train and test
# 80-20 Ratio

# %%
train, test = train_test_split(dataset, test_size=0.2, random_state=42)

print("Train: %i" % len(train))
print("Test: %i" % len(test))
# Out:
# Train: 1024
# Test: 257

# %% [markdown]
# ## Visualising the data and features

# %%
plt.figure(figsize=(20,10))
idx = 0
for label in dataset.label.unique():    
    y, sr = librosa.load(dataset[dataset.label==label].filename.iloc[33], duration=3)
    print(dataset[dataset.label==label].filename.iloc[33])
    
    # Wave plot
    idx+=1
    plt.subplot(2, 3, idx)
    plt.title("%s waveplot" % label)
    librosa.display.waveplot(y, sr=sr)

    # Mel Spectrogram
    idx+=1
    plt.subplot(2, 3, idx)
    S = librosa.feature.melspectrogram(y, sr=sr, n_fft=2048, hop_length=512, n_mels=128)
    S_DB = librosa.power_to_db(S, ref=np.max)
    librosa.display.specshow(S_DB, sr=sr, hop_length=512, x_axis='time', y_axis='mel')
    plt.title("%s mel spectogram" % label)

    # MFCC (Mel spectrogram)
    idx+=1
    mfccs = librosa.feature.mfcc(S=librosa.power_to_db(S), n_mfcc=40)
    plt.subplot(2, 3, idx)
    librosa.display.specshow(mfccs, x_axis='time')
    plt.title("%s mfcc(Mel Spectrogram)" % label)
plt.show()
# Out:
# ./set_b\normal__137_1306764999211_C.wav
# ./set_b\extrastole__220_1308250132896_B.wav

# %% [markdown]
# ## Extracting features

# %%
def extract_features(audio_path,offset):
#     y, sr = librosa.load(audio_path, duration=3)
    y, sr = librosa.load(audio_path, offset=offset, duration=3)
#     y = librosa.util.normalize(y)
    
    S = librosa.feature.melspectrogram(y, sr=sr, n_fft=2048, 
                                   hop_length=512, 
                                   n_mels=128)
    mfccs = librosa.feature.mfcc(S=librosa.power_to_db(S), n_mfcc=40)

#     mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40)
    return mfccs

# %%
x_train = []
x_test = []

for idx in tqdm(range(len(train))):
    x_train.append(extract_features(train.filename.iloc[idx],train.offset.iloc[idx]))

for idx in tqdm(range(len(test))):
    x_test.append(extract_features(test.filename.iloc[idx],test.offset.iloc[idx]))
    
x_test = np.asarray(x_test)
x_train = np.asarray(x_train)

print("X train:", x_train.shape)
print("X test:", x_test.shape)
# Out:
# 100%|██████████| 1024/1024 [02:31<00:00,  6.76it/s]
# 100%|██████████| 257/257 [00:38<00:00,  6.63it/s]X train: (1024, 40, 130)
# X test: (257, 40, 130)

# %%
# Encode Labels
encoder = LabelEncoder()
encoder.fit(train.label)

y_train = encoder.transform(train.label)
y_test = encoder.transform(test.label)

# Compute class weights
print(np.unique(y_train))

class_test = class_weight.compute_class_weight('balanced',np.unique(y_train),y_train)
class_weights = {0:class_test[0],1:class_test[1]}
print(class_weights)
print(type(class_weights))
# Out:
# [0 1]
# {0: 1.2673267326732673, 1: 0.8258064516129032}
# <class 'dict'>

# %% [markdown]
# ## Input Shapes

# %%
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], x_test.shape[2], 1)
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

print("X train:", x_train.shape)
print("Y train:", y_train.shape)
print("X test:", x_test.shape)
print("Y test:", y_test.shape)
# Out:
# X train: (1024, 40, 130, 1)
# Y train: (1024, 2)
# X test: (257, 40, 130, 1)
# Y test: (257, 2)

# %% [markdown]
# ## Building Model

# %%
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, input_shape=(x_train.shape[1],x_train.shape[2],x_train.shape[3]), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=32, kernel_size=2, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=2, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=128, kernel_size=2, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.5))
model.add(GlobalAveragePooling2D())

model.add(Dense(len(encoder.classes_), activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 39, 129, 16)       80
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 19, 64, 16)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 19, 64, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 18, 63, 32)        2080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 31, 32)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 31, 32)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 30, 64)         8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 15, 64)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 15, 64)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 14, 128)        32896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 7, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 7, 128)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 258
# =================================================================
# Total params: 43,570
# Trainable params: 43,570
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compiling Model

# %%
adam = keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %% [markdown]
# ## Fitting Model

# %%
# %%time
history = model.fit(x_train, y_train,
              batch_size=128,
              epochs=300,
              validation_data=(x_test, y_test),
              class_weight=class_weights,
              shuffle=True)
# Out:
# Epoch 1/300
# 8/8 [==============================] - 1s 168ms/step - loss: 9.0933 - accuracy: 0.4785 - val_loss: 1.8705 - val_accuracy: 0.5798
# Epoch 2/300
# 8/8 [==============================] - 0s 51ms/step - loss: 3.4805 - accuracy: 0.5273 - val_loss: 2.4239 - val_accuracy: 0.4202
# Epoch 3/300
# 8/8 [==============================] - 0s 48ms/step - loss: 1.9123 - accuracy: 0.5312 - val_loss: 0.7597 - val_accuracy: 0.6304
# Epoch 4/300
# 8/8 [==============================] - 0s 53ms/step - loss: 1.5275 - accuracy: 0.5576 - val_loss: 0.9455 - val_accuracy: 0.4436
# Epoch 5/300
# 8/8 [==============================] - 0s 54ms/step - loss: 1.1710 - accuracy: 0.4824 - val_loss: 0.6514 - val_accuracy: 0.6226
# Epoch 6/300
# 8/8 [==============================] - 0s 52ms/step - loss: 0.9929 - accuracy: 0.5605 - val_loss: 0.6579 - val_accuracy: 0.6031
# Epoch 7/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.8629 - accuracy: 0.5371 - val_loss: 0.6494 - val_accuracy: 0.6226
# Epoch 8/300
# 8/8 [==============================] - 0s 47ms/step - loss: 0.8055 - accuracy: 0.5439 - val_loss: 0.6340 - val_accuracy: 0.6576
# Epoch 9/300
# 8/8 [==============================] - 1s 86ms/step - loss: 0.7778 - accuracy: 0.5938 - val_loss: 0.6252 - val_accuracy: 0.7004
# Epoch 10/300
# 8/8 [==============================] - 0s 54ms/step - loss: 0.7586 - accuracy: 0.5840 - val_loss: 0.6176 - val_accuracy: 0.7198
# Epoch 11/300
# 8/8 [==============================] - 0s 59ms/step - loss: 0.7232 - accuracy: 0.6055 - val_loss: 0.6022 - val_accuracy: 0.7121
# Epoch 12/300
# 8/8 [==============================] - 1s 63ms/step - loss: 0.6942 - accuracy: 0.6279 - val_loss: 0.5989 - val_accuracy: 0.7198
# Epoch 13/300
# 8/8 [==============================] - 1s 82ms/step - loss: 0.7014 - accuracy: 0.6074 - val_loss: 0.5948 - val_accuracy: 0.7160
# Epoch 14/300
# 8/8 [==============================] - 1s 119ms/step - loss: 0.6885 - accuracy: 0.6396 - val_loss: 0.5972 - val_accuracy: 0.7276
# Epoch 15/300
# 8/8 [==============================] - 1s 68ms/step - loss: 0.6946 - accuracy: 0.5820 - val_loss: 0.5955 - val_accuracy: 0.7121
# Epoch 16/300
# 8/8 [==============================] - 1s 66ms/step - loss: 0.6543 - accuracy: 0.6475 - val_loss: 0.5930 - val_accuracy: 0.7082
# Epoch 17/300
# 8/8 [==============================] - 1s 74ms/step - loss: 0.6758 - accuracy: 0.6230 - val_loss: 0.5982 - val_accuracy: 0.7160
# Epoch 18/300
# 8/8 [==============================] - 1s 89ms/step - loss: 0.6487 - accuracy: 0.6514 - val_loss: 0.5886 - val_accuracy: 0.7160
# Epoch 19/300
# 8/8 [==============================] - 1s 98ms/step - loss: 0.6501 - accuracy: 0.6621 - val_loss: 0.6002 - val_accuracy: 0.7315
# Epoch 20/300
# 8/8 [==============================] - 1s 95ms/step - loss: 0.6384 - accuracy: 0.6631 - val_loss: 0.5982 - val_accuracy: 0.7315
# Epoch 21/300
# 8/8 [==============================] - 1s 72ms/step - loss: 0.6305 - accuracy: 0.6621 - val_loss: 0.5877 - val_accuracy: 0.7121
# Epoch 22/300
# 8/8 [==============================] - 0s 51ms/step - loss: 0.6395 - accuracy: 0.6631 - val_loss: 0.5925 - val_accuracy: 0.7276
# Epoch 23/300
# 8/8 [==============================] - 0s 52ms/step - loss: 0.6186 - accuracy: 0.6641 - val_loss: 0.5787 - val_accuracy: 0.7588
# Epoch 24/300
# 8/8 [==============================] - 1s 64ms/step - loss: 0.6129 - accuracy: 0.6602 - val_loss: 0.5861 - val_accuracy: 0.7432
# Epoch 25/300
# 8/8 [==============================] - 0s 53ms/step - loss: 0.6061 - accuracy: 0.6855 - val_loss: 0.5886 - val_accuracy: 0.7315
# Epoch 26/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.6079 - accuracy: 0.6768 - val_loss: 0.5855 - val_accuracy: 0.7276
# Epoch 27/300
# 8/8 [==============================] - 0s 50ms/step - loss: 0.6047 - accuracy: 0.6719 - val_loss: 0.5750 - val_accuracy: 0.7393
# Epoch 28/300
# 8/8 [==============================] - 1s 97ms/step - loss: 0.6160 - accuracy: 0.6602 - val_loss: 0.5721 - val_accuracy: 0.7510
# Epoch 29/300
# 8/8 [==============================] - 0s 56ms/step - loss: 0.5867 - accuracy: 0.7041 - val_loss: 0.5656 - val_accuracy: 0.7549
# Epoch 30/300
# 8/8 [==============================] - 1s 84ms/step - loss: 0.6019 - accuracy: 0.6680 - val_loss: 0.5581 - val_accuracy: 0.7393
# Epoch 31/300
# 8/8 [==============================] - 1s 91ms/step - loss: 0.6047 - accuracy: 0.7051 - val_loss: 0.5769 - val_accuracy: 0.7315
# Epoch 32/300
# 8/8 [==============================] - 1s 108ms/step - loss: 0.5884 - accuracy: 0.6758 - val_loss: 0.5663 - val_accuracy: 0.7549
# Epoch 33/300
# 8/8 [==============================] - 1s 87ms/step - loss: 0.5914 - accuracy: 0.6807 - val_loss: 0.5794 - val_accuracy: 0.7043
# Epoch 34/300
# 8/8 [==============================] - 1s 68ms/step - loss: 0.5851 - accuracy: 0.6934 - val_loss: 0.5654 - val_accuracy: 0.7198
# Epoch 35/300
# 8/8 [==============================] - 0s 54ms/step - loss: 0.5944 - accuracy: 0.6992 - val_loss: 0.5652 - val_accuracy: 0.7626
# Epoch 36/300
# 8/8 [==============================] - 1s 67ms/step - loss: 0.5832 - accuracy: 0.6768 - val_loss: 0.5486 - val_accuracy: 0.7354
# Epoch 37/300
# 8/8 [==============================] - 1s 76ms/step - loss: 0.5684 - accuracy: 0.7197 - val_loss: 0.5658 - val_accuracy: 0.7198
# Epoch 38/300
# 8/8 [==============================] - 1s 82ms/step - loss: 0.5686 - accuracy: 0.7002 - val_loss: 0.5444 - val_accuracy: 0.7393
# Epoch 39/300
# 8/8 [==============================] - 1s 70ms/step - loss: 0.5607 - accuracy: 0.7051 - val_loss: 0.5655 - val_accuracy: 0.7198
# Epoch 40/300
# 8/8 [==============================] - 1s 85ms/step - loss: 0.5733 - accuracy: 0.6865 - val_loss: 0.5474 - val_accuracy: 0.7510
# Epoch 41/300
# 8/8 [==============================] - 1s 82ms/step - loss: 0.5547 - accuracy: 0.7129 - val_loss: 0.5532 - val_accuracy: 0.7510
# Epoch 42/300
# 8/8 [==============================] - 1s 87ms/step - loss: 0.5759 - accuracy: 0.6924 - val_loss: 0.5546 - val_accuracy: 0.7354
# Epoch 43/300
# 8/8 [==============================] - 1s 100ms/step - loss: 0.5581 - accuracy: 0.7334 - val_loss: 0.5354 - val_accuracy: 0.7704
# Epoch 44/300
# 8/8 [==============================] - 1s 138ms/step - loss: 0.5588 - accuracy: 0.7168 - val_loss: 0.5400 - val_accuracy: 0.7665
# Epoch 45/300
# 8/8 [==============================] - 0s 57ms/step - loss: 0.5529 - accuracy: 0.7256 - val_loss: 0.5380 - val_accuracy: 0.7471
# Epoch 46/300
# 8/8 [==============================] - 1s 66ms/step - loss: 0.5578 - accuracy: 0.7168 - val_loss: 0.5369 - val_accuracy: 0.7626
# Epoch 47/300
# 8/8 [==============================] - 1s 68ms/step - loss: 0.5459 - accuracy: 0.7207 - val_loss: 0.5287 - val_accuracy: 0.7549
# Epoch 48/300
# 8/8 [==============================] - 0s 61ms/step - loss: 0.5557 - accuracy: 0.7100 - val_loss: 0.5392 - val_accuracy: 0.7510
# Epoch 49/300
# 8/8 [==============================] - 1s 69ms/step - loss: 0.5401 - accuracy: 0.7305 - val_loss: 0.5358 - val_accuracy: 0.7471
# Epoch 50/300
# 8/8 [==============================] - 1s 86ms/step - loss: 0.5415 - accuracy: 0.7109 - val_loss: 0.5282 - val_accuracy: 0.7432
# Epoch 51/300
# 8/8 [==============================] - 1s 112ms/step - loss: 0.5470 - accuracy: 0.7227 - val_loss: 0.5283 - val_accuracy: 0.7665
# Epoch 52/300
# 8/8 [==============================] - 1s 82ms/step - loss: 0.5361 - accuracy: 0.7402 - val_loss: 0.5560 - val_accuracy: 0.7315
# Epoch 53/300
# 8/8 [==============================] - 1s 148ms/step - loss: 0.5435 - accuracy: 0.7227 - val_loss: 0.5164 - val_accuracy: 0.7471
# Epoch 54/300
# 8/8 [==============================] - 1s 116ms/step - loss: 0.5591 - accuracy: 0.7129 - val_loss: 0.5223 - val_accuracy: 0.7665
# Epoch 55/300
# 8/8 [==============================] - 1s 154ms/step - loss: 0.5417 - accuracy: 0.7402 - val_loss: 0.5238 - val_accuracy: 0.7432
# Epoch 56/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.5537 - accuracy: 0.7119 - val_loss: 0.5248 - val_accuracy: 0.7471
# Epoch 57/300
# 8/8 [==============================] - 0s 62ms/step - loss: 0.5230 - accuracy: 0.7441 - val_loss: 0.5412 - val_accuracy: 0.7432
# Epoch 58/300
# 8/8 [==============================] - 0s 59ms/step - loss: 0.5410 - accuracy: 0.7354 - val_loss: 0.5434 - val_accuracy: 0.7432
# Epoch 59/300
# 8/8 [==============================] - 0s 56ms/step - loss: 0.5454 - accuracy: 0.7266 - val_loss: 0.5214 - val_accuracy: 0.7510
# Epoch 60/300
# 8/8 [==============================] - 1s 83ms/step - loss: 0.5246 - accuracy: 0.7471 - val_loss: 0.5340 - val_accuracy: 0.7432
# Epoch 61/300
# 8/8 [==============================] - 1s 74ms/step - loss: 0.5281 - accuracy: 0.7334 - val_loss: 0.5175 - val_accuracy: 0.7588
# Epoch 62/300
# 8/8 [==============================] - 0s 58ms/step - loss: 0.5222 - accuracy: 0.7432 - val_loss: 0.5145 - val_accuracy: 0.7588
# Epoch 63/300
# 8/8 [==============================] - 0s 61ms/step - loss: 0.5218 - accuracy: 0.7451 - val_loss: 0.5274 - val_accuracy: 0.7510
# Epoch 64/300
# 8/8 [==============================] - 1s 74ms/step - loss: 0.5258 - accuracy: 0.7334 - val_loss: 0.5227 - val_accuracy: 0.7510
# Epoch 65/300
# 8/8 [==============================] - 1s 75ms/step - loss: 0.5355 - accuracy: 0.7188 - val_loss: 0.5486 - val_accuracy: 0.7276
# Epoch 66/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0
300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.5114 - accuracy: 0.7461 - val_loss: 0.5062 - val_accuracy: 0.7588
# Epoch 87/300
# 8/8 [==============================] - 1s 89ms/step - loss: 0.5063 - accuracy: 0.7695 - val_loss: 0.5020 - val_accuracy: 0.7471
# Epoch 88/300
# 8/8 [==============================] - 1s 108ms/step - loss: 0.4959 - accuracy: 0.7461 - val_loss: 0.4900 - val_accuracy: 0.7704
# Epoch 89/300
# 8/8 [==============================] - 1s 83ms/step - loss: 0.5064 - accuracy: 0.7529 - val_loss: 0.5093 - val_accuracy: 0.7665
# Epoch 90/300
# 8/8 [==============================] - 1s 111ms/step - loss: 0.4811 - accuracy: 0.7607 - val_loss: 0.4663 - val_accuracy: 0.7821
# Epoch 91/300
# 8/8 [==============================] - 1s 70ms/step - loss: 0.4950 - accuracy: 0.7568 - val_loss: 0.4875 - val_accuracy: 0.7626
# Epoch 92/300
# 8/8 [==============================] - 1s 93ms/step - loss: 0.4973 - accuracy: 0.7646 - val_loss: 0.5157 - val_accuracy: 0.7549
# Epoch 93/300
# 8/8 [==============================] - 1s 83ms/step - loss: 0.4938 - accuracy: 0.7461 - val_loss: 0.4804 - val_accuracy: 0.7626
# Epoch 94/300
# 8/8 [==============================] - 0s 57ms/step - loss: 0.4984 - accuracy: 0.7334 - val_loss: 0.4747 - val_accuracy: 0.7704
# Epoch 95/300
# 8/8 [==============================] - 0s 56ms/step - loss: 0.4858 - accuracy: 0.7715 - val_loss: 0.4964 - val_accuracy: 0.7549
# Epoch 96/300
# 8/8 [==============================] - 0s 60ms/step - loss: 0.4741 - accuracy: 0.7744 - val_loss: 0.4825 - val_accuracy: 0.7977
# Epoch 97/300
# 8/8 [==============================] - 1s 75ms/step - loss: 0.4922 - accuracy: 0.7627 - val_loss: 0.4587 - val_accuracy: 0.7899
# Epoch 98/300
# 8/8 [==============================] - 1s 124ms/step - loss: 0.4918 - accuracy: 0.7520 - val_loss: 0.4895 - val_accuracy: 0.7626
# Epoch 99/300
# 8/8 [==============================] - 1s 87ms/step - loss: 0.4871 - accuracy: 0.7725 - val_loss: 0.4879 - val_accuracy: 0.7626
# Epoch 100/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.4813 - accuracy: 0.7617 - val_loss: 0.4627 - val_accuracy: 0.7743
# Epoch 101/300
# 8/8 [==============================] - 1s 87ms/step - loss: 0.5031 - accuracy: 0.7500 - val_loss: 0.4674 - val_accuracy: 0.7665
# Epoch 102/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.4825 - accuracy: 0.7656 - val_loss: 0.4754 - val_accuracy: 0.7626
# Epoch 103/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.4822 - accuracy: 0.7744 - val_loss: 0.4907 - val_accuracy: 0.7704
# Epoch 104/300
# 8/8 [==============================] - 1s 72ms/step - loss: 0.4907 - accuracy: 0.7598 - val_loss: 0.4793 - val_accuracy: 0.7782
# Epoch 105/300
# 8/8 [==============================] - 1s 71ms/step - loss: 0.4671 - accuracy: 0.7832 - val_loss: 0.4716 - val_accuracy: 0.7860
# Epoch 106/300
# 8/8 [==============================] - 1s 90ms/step - loss: 0.4653 - accuracy: 0.7666 - val_loss: 0.4786 - val_accuracy: 0.7821
# Epoch 107/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0
300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.4028 - accuracy: 0.8145 - val_loss: 0.3933 - val_accuracy: 0.7938
# Epoch 173/300
# 8/8 [==============================] - 1s 105ms/step - loss: 0.3938 - accuracy: 0.8047 - val_loss: 0.4025 - val_accuracy: 0.8171
# Epoch 174/300
# 8/8 [==============================] - 1s 65ms/step - loss: 0.3733 - accuracy: 0.8320 - val_loss: 0.4114 - val_accuracy: 0.7977
# Epoch 175/300
# 8/8 [==============================] - 1s 84ms/step - loss: 0.3760 - accuracy: 0.8350 - val_loss: 0.3782 - val_accuracy: 0.8249
# Epoch 176/300
# 8/8 [==============================] - 0s 55ms/step - loss: 0.4026 - accuracy: 0.8232 - val_loss: 0.3974 - val_accuracy: 0.8093
# Epoch 177/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.3786 - accuracy: 0.8340 - val_loss: 0.4037 - val_accuracy: 0.7860
# Epoch 178/300
# 8/8 [==============================] - 1s 102ms/step - loss: 0.3620 - accuracy: 0.8291 - val_loss: 0.4184 - val_accuracy: 0.7899
# Epoch 179/300
# 8/8 [==============================] - 1s 92ms/step - loss: 0.3808 - accuracy: 0.7969 - val_loss: 0.3647 - val_accuracy: 0.8171
# Epoch 180/300
# 8/8 [==============================] - 1s 100ms/step - loss: 0.3837 - accuracy: 0.8125 - val_loss: 0.3749 - val_accuracy: 0.8054
# Epoch 181/300
# 8/8 [==============================] - 1s 122ms/step - loss: 0.3730 - accuracy: 0.8350 - val_loss: 0.4440 - val_accuracy: 0.7821
# Epoch 182/300
# 8/8 [==============================] - 1s 86ms/step - loss: 0.4046 - accuracy: 0.8047 - val_loss: 0.4293 - val_accuracy: 0.8016
# Epoch 183/300
# 8/8 [==============================] - 1s 95ms/step - loss: 0.3759 - accuracy: 0.8145 - val_loss: 0.3834 - val_accuracy: 0.8093
# Epoch 184/300
# 8/8 [==============================] - 1s 69ms/step - loss: 0.3631 - accuracy: 0.8359 - val_loss: 0.3929 - val_accuracy: 0.8054
# Epoch 185/300
# 8/8 [==============================] - 1s 109ms/step - loss: 0.3674 - accuracy: 0.8223 - val_loss: 0.3746 - val_accuracy: 0.8132
# Epoch 186/300
# 8/8 [==============================] - 1s 68ms/step - loss: 0.3821 - accuracy: 0.8232 - val_loss: 0.3782 - val_accuracy: 0.8249
# Epoch 187/300
# 8/8 [==============================] - 0s 56ms/step - loss: 0.3758 - accuracy: 0.8271 - val_loss: 0.3816 - val_accuracy: 0.8132
# Epoch 188/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.3551 - accuracy: 0.8555 - val_loss: 0.3668 - val_accuracy: 0.8249
# Epoch 189/300
# 8/8 [==============================] - 1s 118ms/step - loss: 0.3742 - accuracy: 0.8330 - val_loss: 0.3880 - val_accuracy: 0.8249
# Epoch 190/300
# 8/8 [==============================] - 1s 103ms/step - loss: 0.3612 - accuracy: 0.8350 - val_loss: 0.4100 - val_accuracy: 0.7938
# Epoch 191/300
# 8/8 [==============================] - 1s 127ms/step - loss: 0.3506 - accuracy: 0.8477 - val_loss: 0.3803 - val_accuracy: 0.8288
# Epoch 192/300
# 8/8 [==============================] - 1s 130ms/step - loss: 0.3602 - accuracy: 0.8291 - val_loss: 0.3782 - val_accuracy: 0.8327
# Epoch 193/300
# 8/8 [==============================] - 1s 69ms/step - loss: 0.3682 - accuracy: 0.8320 - val_loss: 0.3981 - val_accuracy: 0.8171
# Epoch 194/300
# 8/8 [==============================] - 1s 85ms/step - loss: 0.3605 - accuracy: 0.8438 - val_loss: 0.3646 - val_accuracy: 0.8327
# Epoch 195/300
# 8/8 [==============================] - 1s 82ms/step - loss: 0.3723 - accuracy: 0.8281 - val_loss: 0.3609 - val_accuracy: 0.8210
# Epoch 196/300
# 8/8 [==============================] - 1s 83ms/step - loss: 0.3736 - accuracy: 0.8330 - val_loss: 0.3502 - val_accuracy: 0.8366
# Epoch 197/300
# 8/8 [==============================] - 1s 90ms/step - loss: 0.3859 - accuracy: 0.8135 - val_loss: 0.3580 - val_accuracy: 0.8327
# Epoch 198/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.3786 - accuracy: 0.8252 - val_loss: 0.4099 - val_accuracy: 0.7938
# Epoch 199/300
# 8/8 [==============================] - 1s 98ms/step - loss: 0.3820 - accuracy: 0.8145 - val_loss: 0.4109 - val_accuracy: 0.7899
# Epoch 200/300
# 8/8 [==============================] - 1s 86ms/step - loss: 0.3746 - accuracy: 0.8330 - val_loss: 0.3633 - val_accuracy: 0.8482
# Epoch 201/300
# 8/8 [==============================] - 1s 107ms/step - loss: 0.3543 - accuracy: 0.8232 - val_loss: 0.3558 - val_accuracy: 0.8288
# Epoch 202/300
# 8/8 [==============================] - 1s 74ms/step - loss: 0.3343 - accuracy: 0.8506 - val_loss: 0.3632 - val_accuracy: 0.8327
# Epoch 203/300
# 8/8 [==============================] - 1s 121ms/step - loss: 0.3516 - accuracy: 0.8271 - val_loss: 0.3605 - val_accuracy: 0.8249
# Epoch 204/300
# 8/8 [==============================] - 0s 56ms/step - loss: 0.3618 - accuracy: 0.8389 - val_loss: 0.3785 - val_accuracy: 0.8016
# Epoch 205/300
# 8/8 [==============================] - 1s 87ms/step - loss: 0.3249 - accuracy: 0.8574 - val_loss: 0.3751 - val_accuracy: 0.7977
# Epoch 206/300
# 8/8 [==============================] - 1s 109ms/step - loss: 0.3509 - accuracy: 0.8330 - val_loss: 0.3669 - val_accuracy: 0.8171
# Epoch 207/300
# 8/8 [==============================] - 1s 73ms/step - loss: 0.3557 - accuracy: 0.8389 - val_loss: 0.3646 - val_accuracy: 0.8210
# Epoch 208/300
# 8/8 [==============================] - 1s 72ms/step - loss: 0.3386 - accuracy: 0.8525 - val_loss: 0.3610 - val_accuracy: 0.8132
# Epoch 209/300
# 8/8 [==============================] - 1s 120ms/step - loss: 0.3353 - accuracy: 0.8486 - val_loss: 0.3674 - val_accuracy: 0.8171
# Epoch 210/300
# 8/8 [==============================] - 0s 59ms/step - loss: 0.3405 - accuracy: 0.8457 - val_loss: 0.3405 - val_accuracy: 0.8560
# Epoch 211/300
# 8/8 [==============================] - 1s 122ms/step - loss: 0.3424 - accuracy: 0.8398 - val_loss: 0.3403 - val_accuracy: 0.8444
# Epoch 212/300
# 8/8 [==============================] - 1s 90ms/step - loss: 0.3580 - accuracy: 0.8262 - val_loss: 0.3631 - val_accuracy: 0.8444
# Epoch 213/300
# 8/8 [==============================] - 1s 74ms/step - loss: 0.3276 - accuracy: 0.8486 - val_loss: 0.3842 - val_accuracy: 0.7899
# Epoch 214/300
# 8/8 [==============================] - 0s 59ms/step - loss: 0.3438 - accuracy: 0.8359 - val_loss: 0.3911 - val_accuracy: 0.8288
# Epoch 215/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.3489 - accuracy: 0.8447 - val_loss: 0.3920 - val_accuracy: 0.8093
# Epoch 216/300
# 8/8 [==============================] - 1s 91ms/step - loss: 0.3396 - accuracy: 0.8477 - val_loss: 0.3801 - val_accuracy: 0.8171
# Epoch 217/300
# 8/8 [==============================] - 1s 63ms/step - loss: 0.3373 - accuracy: 0.8506 - val_loss: 0.3426 - val_accuracy: 0.8482
# Epoch 218/300
# 8/8 [==============================] - 1s 67ms/step - loss: 0.3188 - accuracy: 0.8496 - val_loss: 0.3797 - val_accuracy: 0.8093
# Epoch 219/300
# 8/8 [==============================] - 1s 85ms/step - loss: 0.3304 - accuracy: 0.8447 - val_loss: 0.3365 - val_accuracy: 0.8482
# Epoch 220/300
# 8/8 [==============================] - 0s 51ms/step - loss: 0.3276 - accuracy: 0.8545 - val_loss: 0.3395 - val_accuracy: 0.8444
# Epoch 221/300
# 8/8 [==============================] - 1s 64ms/step - loss: 0.3079 - accuracy: 0.8682 - val_loss: 0.3663 - val_accuracy: 0.8093
# Epoch 222/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.3286 - accuracy: 0.8545 - val_loss: 0.3527 - val_accuracy: 0.8482
# Epoch 223/300
# 8/8 [==============================] - 1s 133ms/step - loss: 0.3535 - accuracy: 0.8320 - val_loss: 0.3387 - val_accuracy: 0.8638
# Epoch 224/300
# 8/8 [==============================] - 1s 63ms/step - loss: 0.3159 - accuracy: 0.8564 - val_loss: 0.3281 - val_accuracy: 0.8599
# Epoch 225/300
# 8/8 [==============================] - 1s 76ms/step - loss: 0.3544 - accuracy: 0.8340 - val_loss: 0.3402 - val_accuracy: 0.8444
# Epoch 226/300
# 8/8 [==============================] - 1s 74ms/step - loss: 0.3443 - accuracy: 0.8457 - val_loss: 0.3614 - val_accuracy: 0.8444
# Epoch 227/300
# 8/8 [==============================] - 0s 57ms/step - loss: 0.3142 - accuracy: 0.8633 - val_loss: 0.4036 - val_accuracy: 0.7782
# Epoch 228/300
# 8/8 [==============================] - 1s 95ms/step - loss: 0.3379 - accuracy: 0.8506 - val_loss: 0.3535 - val_accuracy: 0.8327
# Epoch 229/300
# 8/8 [==============================] - 1s 70ms/step - loss: 0.3219 - accuracy: 0.8613 - val_loss: 0.3443 - val_accuracy: 0.8405
# Epoch 230/300
# 8/8 [==============================] - 1s 71ms/step - loss: 0.3043 - accuracy: 0.8652 - val_loss: 0.3273 - val_accuracy: 0.8288
# Epoch 231/300
# 8/8 [==============================] - 0s 57ms/step - loss: 0.3203 - accuracy: 0.8633 - val_loss: 0.3207 - val_accuracy: 0.8677
# Epoch 232/300
# 8/8 [==============================] - 1s 101ms/step - loss: 0.3161 - accuracy: 0.8564 - val_loss: 0.3716 - val_accuracy: 0.8405
# Epoch 233/300
# 8/8 [==============================] - 1s 104ms/step - loss: 0.3256 - accuracy: 0.8506 - val_loss: 0.3896 - val_accuracy: 0.8054
# Epoch 234/300
# 8/8 [==============================] - 1s 92ms/step - loss: 0.3283 - accuracy: 0.8506 - val_loss: 0.3693 - val_accuracy: 0.8171
# Epoch 235/300
# 8/8 [==============================] - 1s 82ms/step - loss: 0.3255 - accuracy: 0.8457 - val_loss: 0.3280 - val_accuracy: 0.8521
# Epoch 236/300
# 8/8 [==============================] - 0s 60ms/step - loss: 0.3239 - accuracy: 0.8525 - val_loss: 0.3370 - val_accuracy: 0.8288
# Epoch 237/300
# 8/8 [==============================] - 1s 86ms/step - loss: 0.2908 - accuracy: 0.8818 - val_loss: 0.3490 - val_accuracy: 0.8482
# Epoch 238/300
# 8/8 [==============================] - 0s 59ms/step - loss: 0.2951 - accuracy: 0.8682 - val_loss: 0.3293 - val_accuracy: 0.8677
# Epoch 239/300
# 8/8 [==============================] - 1s 91ms/step - loss: 0.2980 - accuracy: 0.8721 - val_loss: 0.3176 - val_accuracy: 0.8638
# Epoch 240/300
# 8/8 [==============================] - 1s 89ms/step - loss: 0.2956 - accuracy: 0.8740 - val_loss: 0.3351 - val_accuracy: 0.8482
# Epoch 241/300
# 8/8 [==============================] - 1s 94ms/step - loss: 0.2813 - accuracy: 0.8760 - val_loss: 0.3348 - val_accuracy: 0.8327
# Epoch 242/300
# 8/8 [==============================] - 1s 71ms/step - loss: 0.3126 - accuracy: 0.8516 - val_loss: 0.3661 - val_accuracy: 0.8327
# Epoch 243/300
# 8/8 [==============================] - 1s 64ms/step - loss: 0.3040 - accuracy: 0.8779 - val_loss: 0.3605 - val_accuracy: 0.8210
# Epoch 244/300
# 8/8 [==============================] - 1s 107ms/step - loss: 0.2792 - accuracy: 0.8799 - val_loss: 0.3433 - val_accuracy: 0.8405
# Epoch 245/300
# 8/8 [==============================] - 1s 98ms/step - loss: 0.2995 - accuracy: 0.8691 - val_loss: 0.3401 - val_accuracy: 0.8405
# Epoch 246/300
# 8/8 [==============================] - 1s 105ms/step - loss: 0.3113 - accuracy: 0.8633 - val_loss: 0.3254 - val_accuracy: 0.8405
# Epoch 247/300
# 8/8 [==============================] - 1s 86ms/step - loss: 0.2757 - accuracy: 0.8750 - val_loss: 0.3285 - val_accuracy: 0.8482
# Epoch 248/300
# 8/8 [==============================] - 1s 92ms/step - loss: 0.2815 - accuracy: 0.8730 - val_loss: 0.3280 - val_accuracy: 0.8444
# Epoch 249/300
# 8/8 [==============================] - 1s 87ms/step - loss: 0.3100 - accuracy: 0.8574 - val_loss: 0.3261 - val_accuracy: 0.8560
# Epoch 250/300
# 8/8 [==============================] - 1s 71ms/step - loss: 0.3008 - accuracy: 0.8682 - val_loss: 0.3280 - val_accuracy: 0.8405
# Epoch 251/300
# 8/8 [==============================] - 1s 108ms/step - loss: 0.2767 - accuracy: 0.8906 - val_loss: 0.3274 - val_accuracy: 0.8677
# Epoch 252/300
# 8/8 [==============================] - 1s 63ms/step - loss: 0.2783 - accuracy: 0.8818 - val_loss: 0.3310 - val_accuracy: 0.8560
# Epoch 253/300
# 8/8 [==============================] - 1s 110ms/step - loss: 0.3016 - accuracy: 0.8633 - val_loss: 0.3416 - val_accuracy: 0.8638
# Epoch 254/300
# 8/8 [==============================] - 1s 87ms/step - loss: 0.2845 - accuracy: 0.8809 - val_loss: 0.3590 - val_accuracy: 0.8210
# Epoch 255/300
# 8/8 [==============================] - 1s 73ms/step - loss: 0.2925 - accuracy: 0.8721 - val_loss: 0.3271 - val_accuracy: 0.8599
# Epoch 256/300
# 8/8 [==============================] - 1s 145ms/step - loss: 0.2922 - accuracy: 0.8740 - val_loss: 0.3174 - val_accuracy: 0.8560
# Epoch 257/300
# 8/8 [==============================] - 0s 56ms/step - loss: 0.2759 - accuracy: 0.8770 - val_loss: 0.3160 - val_accuracy: 0.8560
# Epoch 258/300
# 8/8 [==============================] - 1s 102ms/step - loss: 0.2818 - accuracy: 0.8857 - val_loss: 0.3154 - val_accuracy: 0.8560
# Epoch 259/300
# 8/8 [==============================] - 1s 64ms/step - loss: 0.2657 - accuracy: 0.8809 - val_loss: 0.3310 - val_accuracy: 0.8560
# Epoch 260/300
# 8/8 [==============================] - 1s 86ms/step - loss: 0.3033 - accuracy: 0.8652 - val_loss: 0.3841 - val_accuracy: 0.8171
# Epoch 261/300
# 8/8 [==============================] - 1s 69ms/step - loss: 0.3317 - accuracy: 0.8486 - val_loss: 0.3957 - val_accuracy: 0.8054
# Epoch 262/300
# 8/8 [==============================] - 1s 72ms/step - loss: 0.2855 - accuracy: 0.8740 - val_loss: 0.3078 - val_accuracy: 0.8638
# Epoch 263/300
# 8/8 [==============================] - 1s 84ms/step - loss: 0.2743 - accuracy: 0.8838 - val_loss: 0.3108 - val_accuracy: 0.8872
# Epoch 264/300
# 8/8 [==============================] - 1s 112ms/step - loss: 0.2793 - accuracy: 0.8828 - val_loss: 0.3112 - val_accuracy: 0.8560
# Epoch 265/300
# 8/8 [==============================] - 1s 74ms/step - loss: 0.2674 - accuracy: 0.8857 - val_loss: 0.3223 - val_accuracy: 0.8444
# Epoch 266/300
# 8/8 [==============================] - 1s 66ms/step - loss: 0.2944 - accuracy: 0.8643 - val_loss: 0.3209 - val_accuracy: 0.8638
# Epoch 267/300
# 8/8 [==============================] - 1s 90ms/step - loss: 0.2710 - accuracy: 0.8809 - val_loss: 0.3301 - val_accuracy: 0.8366
# Epoch 268/300
# 8/8 [==============================] - 0s 62ms/step - loss: 0.2864 - accuracy: 0.8760 - val_loss: 0.3392 - val_accuracy: 0.8366
# Epoch 269/300
# 8/8 [==============================] - 0s 53ms/step - loss: 0.2618 - accuracy: 0.8945 - val_loss: 0.3327 - val_accuracy: 0.8677
# Epoch 270/300
# 8/8 [==============================] - 1s 69ms/step - loss: 0.2747 - accuracy: 0.8760 - val_loss: 0.3145 - val_accuracy: 0.8638
# Epoch 271/300
# 8/8 [==============================] - 1s 74ms/step - loss: 0.2646 - accuracy: 0.8857 - val_loss: 0.3271 - val_accuracy: 0.8521
# Epoch 272/300
# 8/8 [==============================] - 1s 85ms/step - loss: 0.2899 - accuracy: 0.8643 - val_loss: 0.3683 - val_accuracy: 0.8171
# Epoch 273/300
# 8/8 [==============================] - 1s 99ms/step - loss: 0.2707 - accuracy: 0.8896 - val_loss: 0.3138 - val_accuracy: 0.8638
# Epoch 274/300
# 8/8 [==============================] - 1s 100ms/step - loss: 0.2742 - accuracy: 0.8887 - val_loss: 0.3116 - val_accuracy: 0.8677
# Epoch 275/300
# 8/8 [==============================] - 1s 91ms/step - loss: 0.3033 - accuracy: 0.8711 - val_loss: 0.3422 - val_accuracy: 0.8444
# Epoch 276/300
# 8/8 [==============================] - 1s 94ms/step - loss: 0.2807 - accuracy: 0.8838 - val_loss: 0.3353 - val_accuracy: 0.8560
# Epoch 277/300
# 8/8 [==============================] - 1s 125ms/step - loss: 0.2808 - accuracy: 0.8701 - val_loss: 0.3186 - val_accuracy: 0.8599
# Epoch 278/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.2687 - accuracy: 0.8750 - val_loss: 0.3141 - val_accuracy: 0.8405
# Epoch 279/300
# 8/8 [==============================] - 1s 67ms/step - loss: 0.2765 - accuracy: 0.8760 - val_loss: 0.3265 - val_accuracy: 0.8444
# Epoch 280/300
# 8/8 [==============================] - 0s 60ms/step - loss: 0.2699 - accuracy: 0.8721 - val_loss: 0.3279 - val_accuracy: 0.8716
# Epoch 281/300
# 8/8 [==============================] - 1s 76ms/step - loss: 0.2902 - accuracy: 0.8779 - val_loss: 0.3445 - val_accuracy: 0.8366
# Epoch 282/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.2578 - accuracy: 0.8916 - val_loss: 0.3155 - val_accuracy: 0.8794
# Epoch 283/300
# 8/8 [==============================] - 0s 61ms/step - loss: 0.2405 - accuracy: 0.9072 - val_loss: 0.3181 - val_accuracy: 0.8327
# Epoch 284/300
# 8/8 [==============================] - 1s 67ms/step - loss: 0.2631 - accuracy: 0.8828 - val_loss: 0.3144 - val_accuracy: 0.8560
# Epoch 285/300
# 8/8 [==============================] - 1s 70ms/step - loss: 0.2617 - accuracy: 0.8906 - val_loss: 0.3374 - val_accuracy: 0.8288
# Epoch 286/300
# 8/8 [==============================] - 1s 124ms/step - loss: 0.2458 - accuracy: 0.9004 - val_loss: 0.3021 - val_accuracy: 0.8599
# Epoch 287/300
# 8/8 [==============================] - 1s 85ms/step - loss: 0.2424 - accuracy: 0.8975 - val_loss: 0.3097 - val_accuracy: 0.8560
# Epoch 288/300
# 8/8 [==============================] - 1s 93ms/step - loss: 0.2861 - accuracy: 0.8740 - val_loss: 0.3063 - val_accuracy: 0.8755
# Epoch 289/300
# 8/8 [==============================] - 1s 106ms/step - loss: 0.2570 - accuracy: 0.8877 - val_loss: 0.3207 - val_accuracy: 0.8288
# Epoch 290/300
# 8/8 [==============================] - 1s 64ms/step - loss: 0.2789 - accuracy: 0.8740 - val_loss: 0.3184 - val_accuracy: 0.8638
# Epoch 291/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.2392 - accuracy: 0.8984 - val_loss: 0.3243 - val_accuracy: 0.8327
# Epoch 292/300
# 8/8 [==============================] - 0s 57ms/step - loss: 0.2854 - accuracy: 0.8730 - val_loss: 0.3084 - val_accuracy: 0.8599
# Epoch 293/300
# 8/8 [==============================] - 1s 66ms/step - loss: 0.2484 - accuracy: 0.8896 - val_loss: 0.2934 - val_accuracy: 0.8755
# Epoch 294/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.2420 - accuracy: 0.9004 - val_loss: 0.3154 - val_accuracy: 0.8599
# Epoch 295/300
# 8/8 [==============================] - 1s 91ms/step - loss: 0.2566 - accuracy: 0.8877 - val_loss: 0.3166 - val_accuracy: 0.8677
# Epoch 296/300
# 8/8 [==============================] - 1s 71ms/step - loss: 0.2582 - accuracy: 0.8926 - val_loss: 0.3194 - val_accuracy: 0.8444
# Epoch 297/300
# 8/8 [==============================] - 1s 90ms/step - loss: 0.2329 - accuracy: 0.9004 - val_loss: 0.3165 - val_accuracy: 0.8560
# Epoch 298/300
# 8/8 [==============================] - 1s 71ms/step - loss: 0.2512 - accuracy: 0.8867 - val_loss: 0.3142 - val_accuracy: 0.8599
# Epoch 299/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.2431 - accuracy: 0.8936 - val_loss: 0.2965 - val_accuracy: 0.8638
# Epoch 300/300
# 8/8 [==============================] - 1s 84ms/step - loss: 0.2225 - accuracy: 0.9004 - val_loss: 0.2956 - val_accuracy: 0.8638
# Wall time: 3min 35s

# %% [markdown]
# ## Evaluating model

# %%
# Loss Curves
plt.figure(figsize=[14,10])
plt.subplot(211)
plt.plot(history.history['loss'],'#d62728',linewidth=3.0)
plt.plot(history.history['val_loss'],'#1f77b4',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=16)
 
# Accuracy Curves
plt.figure(figsize=[14,10])
plt.subplot(212)
plt.plot(history.history['accuracy'],'#d62728',linewidth=3.0)
plt.plot(history.history['val_accuracy'],'#1f77b4',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Accuracy',fontsize=16)
plt.title('Accuracy Curves',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Accuracy Curves')

# %%
print(x_test.shape)
print(y_train.shape)
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# (257, 40, 130, 1)
# (1024, 2)
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2956 - accuracy: 0.8638
# Test loss: 0.29562869668006897
# Test accuracy: 0.8638132214546204

# %%
predictions = model.predict(x_test, verbose=1)

y_true, y_pred = [],[]
classes = encoder.classes_
for idx, prediction in enumerate(predictions): 
    y_true.append(classes[np.argmax(y_test[idx])])
    y_pred.append(classes[np.argmax(prediction)])
    
print(classification_report(y_pred, y_true))
# Out:
# 9/9 [==============================] - 0s 4ms/step
#               precision    recall  f1-score   support
#
#     abnormal       0.85      0.83      0.84       111
#       normal       0.87      0.89      0.88       146
#
#     accuracy                           0.86       257
#    macro avg       0.86      0.86      0.86       257
# weighted avg       0.86      0.86      0.86       257

# %% [markdown]
# ### Save Model and Weights

# %%
model_name = "heartbeat.h5"
model.save(model_name)

# %%
# 1 sec overlap
# Trained for 3sec for files >3sec

# %% [markdown]
# ### Classifying an heart beat

# %%
# load and evaluate a saved model
from keras.models import load_model
 
# load model
model = load_model("heartbeat_classifier.h5")

# File to be classified
classify_file = "c0001.wav"
x_test = []
x_test.append(extract_features(classify_file,0.5))
x_test = np.asarray(x_test)
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], x_test.shape[2], 1)
pred = model.predict(x_test,verbose=1)

print(pred)
# Out:
# 1/1 [==============================] - 0s 4ms/step
# [[0.9979917  0.00200832]]

# %%
pred_class = model.predict_classes(x_test)
if pred_class[0]:
    print("Normal heartbeat")
    print("confidence:",pred[0][1])
else:
    print("Abnormal heartbeat")
    print("confidence:",pred[0][0])
# Out:
# WARNING:tensorflow:From <ipython-input-21-321101c504e4>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# Abnormal heartbeat
# confidence: 0.9979917
